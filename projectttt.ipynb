# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\raksh\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\raksh\anaconda3\lib\site-packages (from langchain) (0.3.81)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\raksh\anaconda3\lib\site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\raksh\anaconda3\lib\site-packages (from langchain) (0.4.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\raksh\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\raksh\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\raksh\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\raksh\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\raksh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\raksh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\raksh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.11.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\raksh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (24.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\raksh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\raksh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\raksh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\raksh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\raksh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\raksh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\raksh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raksh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raksh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raksh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\raksh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in c:\users\raksh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\raksh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\raksh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\raksh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\raksh\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (2.1)

# %%
import langchain
print(langchain.__version__)
# Out:
# 0.3.27

# %%
from langchain.document_loaders import TextLoader

# %%
loader=TextLoader("nvda_news_1.txt")
data=loader.load()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 loader=TextLoader("nvda_news_1.txt")
#       2 data=loader.load()
#
# NameError: name 'TextLoader' is not defined

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("nvda_news_1.txt")
data = loader.load()

print(data[0].page_content)
# Out:
# The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly overvalued? This article aims to provide a detailed valuation analysis of NVIDIA, offering insights into its financial strength, profitability, growth, and more. We invite you to delve into this comprehensive analysis.
#
# Company Overview
# Warning! GuruFocus has detected 10 Warning Signs with NVDA. Click here to check it out.
#
# NVDA 30-Year Financial Data
#
# The intrinsic value of NVDA
#
#
# NVIDIA Corp (NASDAQ:NVDA) is a leading designer of discrete graphics processing units that enhance the experience on computing platforms. The firm's chips are widely used in various end markets, including PC gaming and data centers. In recent years, NVIDIA has broadened its focus from traditional PC graphics applications such as gaming to more complex and favorable opportunities, including artificial intelligence and autonomous driving, leveraging the high-performance capabilities of its products.
#
# Currently, NVIDIA's stock price stands at $418.01, significantly higher than the GF Value of $310.28, indicating the stock might be overvalued. With a market cap of $1 trillion, the valuation seems steep. The following analysis aims to delve deeper into the company's value.
#
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Understanding the GF Value
# The GF Value is a unique measure of the intrinsic value of a stock, calculated based on historical trading multiples, a GuruFocus adjustment factor, and future business performance estimates. If the stock price is significantly above the GF Value Line, it is overvalued, and its future return is likely to be poor. Conversely, if it is significantly below the GF Value Line, its future return will likely be higher.
#
# According to GuruFocus Value calculation, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. The stock's current price of $418.01 per share and the market cap of $1 trillion further strengthen this assumption.
#
# Given that NVIDIA is significantly overvalued, the long-term return of its stock is likely to be much lower than its future business growth.
#
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Link: These companies may deliver higher future returns at reduced risk.
#
# Financial Strength of NVIDIA
# Examining the financial strength of a company is crucial before investing in its stock. Companies with poor financial strength pose a higher risk of permanent loss. NVIDIA's cash-to-debt ratio of 1.27 is worse than 58.04% of companies in the Semiconductors industry. However, NVIDIA's overall financial strength is 8 out of 10, indicating a strong financial position.
#
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Profitability and Growth
# Consistent profitability over the long term reduces the risk for investors. NVIDIA, with its profitability ranking of 10 out of 10, has been profitable for the past 10 years. The company's operating margin of 17.37% ranks better than 76.5% of companies in the Semiconductors industry.
#
# However, growth is a crucial factor in a company's valuation. NVIDIA's growth ranks worse than 52.99% of companies in the Semiconductors industry, with its 3-year average revenue growth rate better than 87.88% of companies in the industry.
#
# ROIC vs WACC
# Comparing a company's return on invested capital (ROIC) to its weighted average cost of capital (WACC) is an effective way to evaluate its profitability. Over the past 12 months, NVIDIA's ROIC was 20.32 while its WACC was 16.74, suggesting that the company is creating value for its shareholders.
#
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Conclusion
# In conclusion, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. Despite its strong financial condition and profitability, its growth ranks lower than 52.99% of companies in the Semiconductors industry. To learn more about NVIDIA stock, you can check out its 30-Year Financials here.
#
# To find out the high quality companies that may deliver above-average returns, please check out GuruFocus High Quality Low Capex Screener.
#
# This article first appeared on GuruFocus.

# %%
data[0].metadata
# Out:
# {'source': 'nvda_news_1.txt'}

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\raksh\\Downloads'

# %%
from langchain.document_loaders.csv_loader import CSVLoader

# %%
print("TextLoader is working")
# Out:
# TextLoader is working

# %%
loader = CSVLoader(file_path="movies.csv")
data = loader.load()
len(data)
# Out:
# 9

# %%
type(data[0])
# Out:
# langchain_core.documents.base.Document

# %%
data[0].metadata
# Out:
# {'source': 'movies.csv', 'row': 0}

# %%
# !pip3 install unstructured libmagic python-magic python-magic-bin
# Out:
# Collecting unstructured
#   Using cached unstructured-0.18.21-py3-none-any.whl.metadata (25 kB)
# Collecting libmagic
#   Using cached libmagic-1.0.tar.gz (3.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting python-magic
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting python-magic-bin
#   Using cached python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl.metadata (710 bytes)
# Requirement already satisfied: charset-normalizer in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (3.3.2)
# Collecting filetype (from unstructured)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: lxml in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (5.2.1)
# Requirement already satisfied: nltk in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Using cached emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Using cached python_iso639-2025.11.16-py3-none-any.whl.metadata (15 kB)
# Collecting langdetect (from unstructured)
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (1.26.4)
# Collecting rapidfuzz (from unstructured)
#   Using cached rapidfuzz-3.14.3-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (4.11.0)
# Collecting unstructured-client (from unstructured)
#   Using cached unstructured_client-0.42.6-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: tqdm in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (4.66.5)
# Requirement already satisfied: psutil in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (5.9.0)
# Collecting python-oxmsg (from unstructured)
#   Using cached python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\raksh\anaconda3\lib\site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\raksh\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\raksh\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in c:\users\raksh\anaconda3\lib\site-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\raksh\anaconda3\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\raksh\anaconda3\lib\site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in c:\users\raksh\anaconda3\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\raksh\anaconda3\lib\site-packages (from nltk->unstructured) (2024.9.11)
# Collecting olefile (from python-oxmsg->unstructured)
#   Using cached olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raksh\anaconda3\lib\site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raksh\anaconda3\lib\site-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raksh\anaconda3\lib\site-packages (from requests->unstructured) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\raksh\anaconda3\lib\site-packages (from tqdm->unstructured) (0.4.6)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Using cached aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: cryptography>=3.1 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (43.0.0)
# Collecting httpcore>=1.0.9 (from unstructured-client->unstructured)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (0.27.0)
# Collecting pydantic>=2.11.2 (from unstructured-client->unstructured)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting pypdf>=6.2.0 (from unstructured-client->unstructured)
#   Using cached pypdf-6.5.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\raksh\anaconda3\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Collecting h11>=0.16 (from httpcore>=1.0.9->unstructured-client->unstructured)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: anyio in c:\users\raksh\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.2.0)
# Requirement already satisfied: sniffio in c:\users\raksh\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\raksh\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\raksh\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.6.0)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.11.2->unstructured-client->unstructured)
#   Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-extensions (from unstructured)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.11.2->unstructured-client->unstructured)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\raksh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in c:\users\raksh\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.21)
# Using cached unstructured-0.18.21-py3-none-any.whl (1.8 MB)
# Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Using cached python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl (409 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached emoji-2.15.0-py3-none-any.whl (608 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading python_iso639-2025.11.16-py3-none-any.whl (167 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 1.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 1.2 MB/s eta 0:00:00
# Downloading unstructured_client-0.42.6-py3-none-any.whl (219 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 1.3 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading pypdf-6.5.0-py3-none-any.whl (329 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Building wheels for collected packages: libmagic, langdetect
#   Building wheel for libmagic (setup.py): started
#   Building wheel for libmagic (setup.py): finished with status 'done'
#   Created wheel for libmagic: filename=libmagic-1.0-py3-none-any.whl size=4279 sha256=a20be9ed667035645d7146c10c38202d1b55ea5784c38e8764f5429d3bfd188c
#   Stored in directory: c:\users\raksh\appdata\local\pip\cache\wheels\ba\32\b5\da21074580720b7a55fbf1a7597e3b1a325d12940ea6bd661b
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993251 sha256=803116c7a733ed43f42bfda5f8ce6de8548941f87a4b4abe7dbd5481faa94c17
#   Stored in directory: c:\users\raksh\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built libmagic langdetect
# Installing collected packages: python-magic-bin, libmagic, filetype, typing-extensions, rapidfuzz, python-magic, python-iso639, pypdf, olefile, langdetect, html5lib, h11, emoji, backoff, aiofiles, typing-inspection, python-oxmsg, pydantic-core, httpcore, pydantic, unstructured-client, unstructured
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.2
#     Uninstalling httpcore-1.0.2:
#       Successfully uninstalled httpcore-1.0.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
# Successfully installed aiofiles-25.1.0 backoff-2.2.1 emoji-2.15.0 filetype-1.2.0 h11-0.16.0 html5lib-1.1 httpcore-1.0.9 langdetect-1.0.9 libmagic-1.0 olefile-0.47 pydantic-2.12.5 pydantic-core-2.41.5 pypdf-6.5.0 python-iso639-2025.11.16 python-magic-0.4.27 python-magic-bin-0.4.14 python-oxmsg-0.0.2 rapidfuzz-3.14.3 typing-extensions-4.15.0 typing-inspection-0.4.2 unstructured-0.18.21 unstructured-client-0.42.6

# %%
from langchain.document_loaders import UnstructuredURLLoader

# %%
# !pip3 install unstructured libmagic python-magic python-magic-bin
# Out:
# Requirement already satisfied: unstructured in c:\users\raksh\anaconda3\lib\site-packages (0.18.21)
# Requirement already satisfied: libmagic in c:\users\raksh\anaconda3\lib\site-packages (1.0)
# Requirement already satisfied: python-magic in c:\users\raksh\anaconda3\lib\site-packages (0.4.27)
# Requirement already satisfied: python-magic-bin in c:\users\raksh\anaconda3\lib\site-packages (0.4.14)
# Requirement already satisfied: charset-normalizer in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (3.3.2)
# Requirement already satisfied: filetype in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: lxml in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (5.2.1)
# Requirement already satisfied: nltk in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: dataclasses-json in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (2025.11.16)
# Requirement already satisfied: langdetect in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (3.14.3)
# Requirement already satisfied: backoff in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (4.15.0)
# Requirement already satisfied: unstructured-client in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (0.42.6)
# Requirement already satisfied: wrapt in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: tqdm in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (4.66.5)
# Requirement already satisfied: psutil in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (5.9.0)
# Requirement already satisfied: python-oxmsg in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\raksh\anaconda3\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\raksh\anaconda3\lib\site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\raksh\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\raksh\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in c:\users\raksh\anaconda3\lib\site-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\raksh\anaconda3\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\raksh\anaconda3\lib\site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in c:\users\raksh\anaconda3\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\raksh\anaconda3\lib\site-packages (from nltk->unstructured) (2024.9.11)
# Requirement already satisfied: olefile in c:\users\raksh\anaconda3\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raksh\anaconda3\lib\site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raksh\anaconda3\lib\site-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raksh\anaconda3\lib\site-packages (from requests->unstructured) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\raksh\anaconda3\lib\site-packages (from tqdm->unstructured) (0.4.6)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (25.1.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (43.0.0)
# Requirement already satisfied: httpcore>=1.0.9 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (0.27.0)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (2.12.5)
# Requirement already satisfied: pypdf>=6.2.0 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (6.5.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\raksh\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\raksh\anaconda3\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: h11>=0.16 in c:\users\raksh\anaconda3\lib\site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in c:\users\raksh\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.2.0)
# Requirement already satisfied: sniffio in c:\users\raksh\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\raksh\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\raksh\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\raksh\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\raksh\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\raksh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in c:\users\raksh\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.21)

# %%
from langchain.document_loaders import UnstructuredURLLoader

# %%
loader = UnstructuredURLLoader(
    urls = [
        "https://www.moneycontrol.com/news/business/banks/hdfc-bank-re-appoints-sanmoy-chakrabarti-as-chief-risk-officer-11259771.html",
        "https://www.moneycontrol.com/news/business/markets/market-corrects-post-rbi-ups-inflation-forecast-icrr-bet-on-these-top-10-rate-sensitive-stocks-ideas-11142611.html"
    ]
)

# %%
data = loader.load()
len(data)
# Out:
# 2

# %%
data[0].page_content[0:100]
# Out:
# 'English\n\nHindi\n\nGujarati\n\nSpecials\n\nHello, Login\n\nHello, Login\n\nLog-inor Sign-Up\n\nMy Account\n\nMy Pro'

# %%
data[0].metadata
# Out:
# {'source': 'https://www.moneycontrol.com/news/business/banks/hdfc-bank-re-appoints-sanmoy-chakrabarti-as-chief-risk-officer-11259771.html'}

# %%
text = """Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. 
It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. 
Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.

Brothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. 
Kip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. 
Cinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. 
Interstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.

Interstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. 
It has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades."""

# %%
text[0:100]
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher N'

# %%
words = text.split(" ")
len(words)
# Out:
# 264

# %%
chunks = []

s = ""
for word in words:
    s += word + " "
    if len(s)>200:
        chunks.append(s)
        s = ""
        
chunks.append(s)

# %%
chunks[:2]
# Out:
# ['Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt ',
#  'Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in ']

# %%
from langchain.text_splitter import CharacterTextSplitter

splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size=200,
    chunk_overlap=0
)

# %%
chunks = splitter.split_text(text)
len(chunks)
# Out:
# Created a chunk of size 210, which is longer than the specified 200
# Created a chunk of size 208, which is longer than the specified 200
# Created a chunk of size 358, which is longer than the specified 200
# 9

# %%
chunks
# Out:
# ['Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.\n\nBrothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. \nKip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. \nCinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. \nInterstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.\n\nInterstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. \nIt has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades.']

# %%
for chunk in chunks:
    print(len(chunk))
# Out:
# 105
# 120
# 210
# 181
# 197
# 207
# 128
# 357
# 253

# %%
text
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.\n\nBrothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. \nKip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. \nCinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. \nInterstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.\n\nInterstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. \nIt has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades.'

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
r_splitter = RecursiveCharacterTextSplitter(
    separators = ["\n\n", "\n", " "],  # List of separators based on requirement (defaults to ["\n\n", "\n", " "])
    chunk_size = 200,  # size of each chunk created
    chunk_overlap  = 0,  # size of  overlap between chunks in order to maintain the context
    length_function = len  # Function to calculate size, currently we are using "len" which denotes length of string however you can pass any token counter)
)

# %%
chunks = r_splitter.split_text(text)

# %%
for chunk in chunks:
    print(len(chunk))
# Out:
# 105
# 120
# 199
# 10
# 181
# 197
# 198
# 8
# 128
# 191
# 165
# 198
# 54

# %%
first_split = text.split("\n\n")[0]
first_split
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.'

# %%
len(first_split)
# Out:
# 439

# %%
second_split = first_split.split("\n")
second_split
# Out:
# ['Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. ',
#  'It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. ',
#  'Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.']

# %%
for split in second_split:
    print(len(split))
# Out:
# 106
# 121
# 210

# %%
second_split[2]
# Out:
# 'Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.'

# %%
chunks = r_splitter.split_text(text)
for chunk in chunks:
    print (len(chunk))from langchain.text_splitter import RecursiveCharacterTextSplitter

# Sample text
text = """
The stock of NVIDIA Corp experienced a daily loss of -3.56%.
However, over the last 3 months, it gained 32.35%.
EPS of NVIDIA is $1.92.
"""

# Create text splitter
r_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)

# Split text (CORRECT METHOD NAME)
chunks = r_splitter.split_text(text)

# Print chunk lengths
for chunk in chunks:
    print(len(chunk))
    print(chunk)
    print("-----")
# Out:
#   Cell In[6], line 3
#     print (len(chunk))from langchain.text_splitter import RecursiveCharacterTextSplitter
#                       ^
# SyntaxError: invalid syntax

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text = """
The stock of NVIDIA Corp experienced a daily loss of -3.56%.
However, over the last 3 months, it gained 32.35%.
EPS of NVIDIA is $1.92.
"""

r_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)

chunks = r_splitter.split_text(text)

for chunk in chunks:
    print(len(chunk))
    print(chunk)
    print("-----")
# Out:
# 60
# The stock of NVIDIA Corp experienced a daily loss of -3.56%.
# -----
# 74
# However, over the last 3 months, it gained 32.35%.
# EPS of NVIDIA is $1.92.
# -----
